# %% [markdown]
# <a href="https://colab.research.google.com/github/hayaboy/ADP_Practical_Exam/blob/main/Spectral_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import SpectralClustering
from sklearn.datasets import make_moons

# 데이터 생성 (반달 모양 데이터)
X, y = make_moons(n_samples=300, noise=0.1, random_state=0)

# Spectral Clustering 적용
spectral = SpectralClustering(n_clusters=2, affinity='rbf', assign_labels='kmeans', random_state=0)
labels = spectral.fit_predict(X)

# 결과 시각화
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', edgecolor='k')
plt.title('Spectral Clustering')
plt.show()
